# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="gemma:2b")

model
# Out:
# ChatOllama(model='gemma:2b')

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=5
)

splitter

# %%
text = """
    Cricket is one of the most popular sports in the world, especially in countries like India, England, Australia, 
    and Pakistan. It is a game that combines skill, strategy, patience, and teamwork. 
    
    Played in formats ranging from short T20 matches to traditional Test cricket, the sport offers excitement for both players and
    fans. Cricket not only entertains millions but also brings people together, creating a strong sense of passion, 
    rivalry, and national pride.
    
"""

# %%
result = splitter.split_text(text)

result
# Out:
# ['Cricket is one of the most popular sports in the world, especially in countries like India, England, Australia,',
#  'and Pakistan. It is a game that combines skill, strategy, patience, and teamwork.',
#  'Played in formats ranging from short T20 matches to traditional Test cricket, the sport offers excitement for both players and',
#  'fans. Cricket not only entertains millions but also brings people together, creating a strong sense of passion, \n    rivalry, and national pride.']

# %%
len(result)
# Out:
# 4

# %%
type(result)
# Out:
# list
