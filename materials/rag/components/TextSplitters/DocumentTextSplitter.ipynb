# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="gemma:2b")

model
# Out:
# ChatOllama(model='gemma:2b')

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_text_splitters import Language

splitter = RecursiveCharacterTextSplitter.from_language(
    language=Language.MARKDOWN,
    chunk_size=200,
    chunk_overlap=5,
)

splitter

# %%
doc = """
    🧑‍💼 Employee Class in Python — Complete OOP Example

This document explains how to create and use a Python class using Object-Oriented Programming (OOP) principles.
We will build an Employee class step by step, explain all its components, and demonstrate how to create and use objects from it.

📌 What This Document Covers

What a class is

Attributes (instance variables)

Constructor (__init__)

Methods

Object creation

Method invocation

Real-world use case

Fully working Python example

🧠 What Is a Class?

A class in Python is a blueprint for creating objects.
It defines:

What data an object holds (attributes)

What actions an object can perform (methods)

An object is an instance of a class.

🏗️ Employee Class Design
Real-world perspective:

An employee usually has:

An ID

A name

A job role

A salary

An employment status

And can:

View details

Get a raise

Change roles

Be deactivated

Calculate annual salary
"""

# %%
response = splitter.split_text(doc)
response
# Out:
# ['🧑\u200d💼 Employee Class in Python — Complete OOP Example',
#  'This document explains how to create and use a Python class using Object-Oriented Programming (OOP) principles.',
#  'We will build an Employee class step by step, explain all its components, and demonstrate how to create and use objects from it.',
#  '📌 What This Document Covers\n\nWhat a class is\n\nAttributes (instance variables)\n\nConstructor (__init__)\n\nMethods\n\nObject creation\n\nMethod invocation\n\nReal-world use case\n\nFully working Python example',
#  '🧠 What Is a Class?\n\nA class in Python is a blueprint for creating objects.\nIt defines:\n\nWhat data an object holds (attributes)\n\nWhat actions an object can perform (methods)',
#  'An object is an instance of a class.\n\n🏗️ Employee Class Design\nReal-world perspective:\n\nAn employee usually has:\n\nAn ID\n\nA name\n\nA job role\n\nA salary\n\nAn employment status\n\nAnd can:\n\nView details',
# ...

# %%
len(response)
# Out:
# 7
