# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="gemma:2b")

model
# Out:
# ChatOllama(model='gemma:2b')

# %%
pip show langchain-text-splitters
# Out:
# Name: langchain-text-splitters
# Version: 1.1.0
# Summary: LangChain text splitting utilities
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: langchain-core
# Required-by: langchain-classic
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_text_splitters import CharacterTextSplitter

splitter = CharacterTextSplitter(
    chunk_size=70,
    chunk_overlap=5,
    separator=""   # fixed spelling
)

splitter

# %%
text = """
    Cricket is one of the most popular sports in the world, especially in countries like India, England,
    Australia, and Pakistan. It is a game that combines skill, strategy, patience, and teamwork. Played in formats
    ranging from short T20 matches to traditional Test cricket, the sport offers excitement for both players and
    fans. Cricket not only entertains millions but also brings people together, creating a strong sense of passion, 
    rivalry, and national pride.
"""

# %%
result = splitter.split_text(text)
result
# Out:
# ['Cricket is one of the most popular sports in the world, especiall',
#  'cially in countries like India, England,\n    Australia, and Pakistan.',
#  'tan. It is a game that combines skill, strategy, patience, and teamwor',
#  'amwork. Played in formats\n    ranging from short T20 matches to tradit',
#  'raditional Test cricket, the sport offers excitement for both players',
#  'yers and\n    fans. Cricket not only entertains millions but also bring',
#  'brings people together, creating a strong sense of passion, \n    rival',
#  'rivalry, and national pride.']

# %%
len(result)
# Out:
# 8

# %%
type(result)
# Out:
# list
