# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="gemma:2b")

model
# Out:
# ChatOllama(model='gemma:2b')

# %%
from langchain_community.document_loaders import TextLoader

loaders = TextLoader("../data/indian_cricket.txt")

loaders

# %%
data = loaders.load()
data
# Out:
# [Document(metadata={'source': '../data/indian_cricket.txt'}, page_content='Indian cricket walks out in blue and pride,\nFrom dusty maidans to stadiums wide.\nA bat meets hope with a fearless sound,\nDreams rise every time the ball hits the ground.\n\nFrom Gavaskarâ€™s grit to Tendulkarâ€™s grace,\nHistory lives in every crease and face.\nKapilâ€™s leap at Lordâ€™s still echoes loud,\nA nation roaring, fearless and proud.\n\nDhoniâ€™s calm eyes, a finisherâ€™s art,\nPressure melts around his steady heart.\nKohliâ€™s fire, a relentless flame,\nChasing runs, chasing the game.\n\nRohitâ€™s timing, pure and free,\nDouble hundreds, poetry in motion we see.\nBumrahâ€™s run-up, strange yet true,\nWickets fall when he comes through.\n\nSpin weaves magic, Jadeja and Ashwin,\nTurning matches with subtle spin.\nFrom Tests of patience to T20 speed,\nIndian cricket adapts to every need.\n\nLosses teach, victories unite,\nEvery match is a nationâ€™s fight.\nMore than a sport, itâ€™s a shared belief,\nIndian cricketâ€”joy, pain, and relief.\n')]

# %%
type(data)
# Out:
# list

# %%
doc = data[0]
doc
# Out:
# Document(metadata={'source': '../data/indian_cricket.txt'}, page_content='Indian cricket walks out in blue and pride,\nFrom dusty maidans to stadiums wide.\nA bat meets hope with a fearless sound,\nDreams rise every time the ball hits the ground.\n\nFrom Gavaskarâ€™s grit to Tendulkarâ€™s grace,\nHistory lives in every crease and face.\nKapilâ€™s leap at Lordâ€™s still echoes loud,\nA nation roaring, fearless and proud.\n\nDhoniâ€™s calm eyes, a finisherâ€™s art,\nPressure melts around his steady heart.\nKohliâ€™s fire, a relentless flame,\nChasing runs, chasing the game.\n\nRohitâ€™s timing, pure and free,\nDouble hundreds, poetry in motion we see.\nBumrahâ€™s run-up, strange yet true,\nWickets fall when he comes through.\n\nSpin weaves magic, Jadeja and Ashwin,\nTurning matches with subtle spin.\nFrom Tests of patience to T20 speed,\nIndian cricket adapts to every need.\n\nLosses teach, victories unite,\nEvery match is a nationâ€™s fight.\nMore than a sport, itâ€™s a shared belief,\nIndian cricketâ€”joy, pain, and relief.\n')

# %%
doc.page_content
# Out:
# 'Indian cricket walks out in blue and pride,\nFrom dusty maidans to stadiums wide.\nA bat meets hope with a fearless sound,\nDreams rise every time the ball hits the ground.\n\nFrom Gavaskarâ€™s grit to Tendulkarâ€™s grace,\nHistory lives in every crease and face.\nKapilâ€™s leap at Lordâ€™s still echoes loud,\nA nation roaring, fearless and proud.\n\nDhoniâ€™s calm eyes, a finisherâ€™s art,\nPressure melts around his steady heart.\nKohliâ€™s fire, a relentless flame,\nChasing runs, chasing the game.\n\nRohitâ€™s timing, pure and free,\nDouble hundreds, poetry in motion we see.\nBumrahâ€™s run-up, strange yet true,\nWickets fall when he comes through.\n\nSpin weaves magic, Jadeja and Ashwin,\nTurning matches with subtle spin.\nFrom Tests of patience to T20 speed,\nIndian cricket adapts to every need.\n\nLosses teach, victories unite,\nEvery match is a nationâ€™s fight.\nMore than a sport, itâ€™s a shared belief,\nIndian cricketâ€”joy, pain, and relief.\n'

# %%
type(doc)
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# ***now, building a poem summarizer -> by passing loaded document text in LLM***

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    template="""
        summarize the poem: {text} in simple way
    """,
    input_variables=['text']
)

prompt
# Out:
# PromptTemplate(input_variables=['text'], input_types={}, partial_variables={}, template='\n        summarize the poem: {text} in simple way\n    ')

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

parser
# Out:
# StrOutputParser()

# %%
from langchain_core.runnables import RunnableSequence

chain = RunnableSequence(prompt, model, parser)

# %%
response = chain.invoke({'text':doc.page_content})

response
# Out:
# "Sure, here's a summary of the poem:\n\nThe poem celebrates the spirit and passion of Indian cricket. It showcases the resilience and determination of the players and fans who have made the sport a global phenomenon.\n\nThe poem highlights the rich history and cultural significance of cricket in India, with iconic players and moments that have shaped the sport's evolution.\n\nIt conveys the unifying power of cricket, with players from all walks of life coming together to cheer for their nation.\n\nThe poem also acknowledges the challenges and sacrifices that the players and fans have made, and how cricket serves as a unifying force for the nation."

# %%
chain.get_graph().print_ascii()
# Out:
#      +-------------+
#      | PromptInput |
#      +-------------+
#             *
#             *
#             *
#     +----------------+
#     | PromptTemplate |
#     +----------------+
#             *
#             *
#             *
#       +------------+
#       | ChatOllama |
#       +------------+
#             *
#             *
#             *
#    +-----------------+
#    | StrOutputParser |
#    +-----------------+
#             *
#             *
#             *
# +-----------------------+
# | StrOutputParserOutput |
# +-----------------------+
