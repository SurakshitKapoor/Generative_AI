# %% [markdown]
# ***building with RunnableLambda***

# %%
# creating a ollama model
from langchain_ollama import ChatOllama

model = ChatOllama(model="gemma:2b")

model
# Out:
# ChatOllama(model='gemma:2b')

# %%
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

parser
# Out:
# StrOutputParser()

# %%
from langchain_core.runnables import RunnableSequence, RunnableParallel, RunnablePassthrough, RunnableLambda

def word_count(s):
    return len(s.split(' '))

ans = word_count("hello my friend")
print(ans)
# Out:
# 3

# %%
from langchain_core.prompts import PromptTemplate

prompt1 = PromptTemplate(
    template="""
        mention simple steps to reach expertise in : {topic}
    """,
    input_variables=['topic']

)

prompt1
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='\n        mention simple steps to reach expertise in : {topic}\n    ')

# %%
sequential_chain = RunnableSequence(prompt1, model, parser)

sequential_chain
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='\n        mention simple steps to reach expertise in : {topic}\n    ')
# | ChatOllama(model='gemma:2b')
# | StrOutputParser()

# %%
parallel_chain = RunnableParallel({
    'roadmap': RunnablePassthrough(),
    'length': RunnableLambda(word_count)
})

parallel_chain
# Out:
# {
#   roadmap: RunnablePassthrough(),
#   length: RunnableLambda(word_count)
# }

# %%
merged_chain = RunnableSequence(sequential_chain, parallel_chain)

merged_chain
# Out:
# PromptTemplate(input_variables=['topic'], input_types={}, partial_variables={}, template='\n        mention simple steps to reach expertise in : {topic}\n    ')
# | ChatOllama(model='gemma:2b')
# | StrOutputParser()
# | {
#     roadmap: RunnablePassthrough(),
#     length: RunnableLambda(word_count)
#   }

# %%
user_input = input("search the roadmap of...")
# Out:
# search the roadmap of... ML Deployment

# %%
response = merged_chain.invoke({"topic":user_input})

response
# Out:
# {'roadmap': '**Simple Steps to Reach Expertise in ML Deployment:**\n\n**1. Fundamentals of Machine Learning:**\n\n* Understand the core concepts of machine learning, including data science, statistical modeling, and deep learning.\n* Learn about the different types of machine learning algorithms and their strengths and weaknesses.\n\n**2. Programming and Data Engineering:**\n\n* Choose a programming language suitable for machine learning, such as Python or R.\n* Learn basic data analysis and manipulation techniques.\n* Explore data preparation tools and libraries for handling and cleaning data.\n\n**3. Cloud Computing Platforms:**\n\n* Understand the basics of cloud computing platforms like AWS, Azure, and Google Cloud Platform.\n* Learn how to deploy and manage machine learning models on the cloud.\n* Explore cloud-based data storage and processing services.\n\n**4. Docker and Kubernetes:**\n\n* Learn what Docker is and how to use it for containerization.\n* Understand Kubernetes and its role in containerized environment.\n* Explore tools like Docker Compose and Kubernetes for deploying and managing ML pipelines.\n\n**5. Data Pipeline Tools:**\n\n* Choose a data pipeline tool such as Airflow, Apache Kafka, or Apache Spark Streaming.\n* Learn how to design, execute, and monitor data pipelines for ML training and deployment.\n\n**6. Model Training and Optimization:**\n\n* Explore techniques for training and optimizing machine learning models, such as hyperparameter tuning and regularization.\n* Learn about data augmentation and early stopping for model improvement.\n\n**7. Containerization and Packaging:**\n\n* Understand the concept of containerization and its benefits for portability.\n* Learn how to package and deploy ML models as Docker images or Kubernetes deployments.\n\n**8. Security and Governance:**\n\n* Implement security measures to protect ML models and data during deployment.\n* Understand the importance of data governance and compliance.\n\n**9. Continuous Monitoring and Maintenance:**\n\n* Set up monitoring and alerting systems to track model performance and system health.\n* Implement proactive maintenance processes to address potential issues.\n\n**10. Case-Based Learning:**\n\n* Choose specific ML deployment use cases, such as building a custom ML pipeline or deploying a model to a production environment.\n* Follow the steps and best practices for deploying that particular use case.\n\n**Additional Tips:**\n\n* Join online communities and forums to connect with other ML deployment experts.\n* Participate in online courses and webinars to stay updated on industry trends.\n* Practice by building and deploying small ML projects.\n* Seek mentorship from experienced ML engineers or data scientists.',
#  'length': 358}

# %%
final_result = """{} word count is: {}""".format(response['roadmap'], response['length'])

final_result
# Out:
# '**Simple Steps to Reach Expertise in ML Deployment:**\n\n**1. Fundamentals of Machine Learning:**\n\n* Understand the core concepts of machine learning, including data science, statistical modeling, and deep learning.\n* Learn about the different types of machine learning algorithms and their strengths and weaknesses.\n\n**2. Programming and Data Engineering:**\n\n* Choose a programming language suitable for machine learning, such as Python or R.\n* Learn basic data analysis and manipulation techniques.\n* Explore data preparation tools and libraries for handling and cleaning data.\n\n**3. Cloud Computing Platforms:**\n\n* Understand the basics of cloud computing platforms like AWS, Azure, and Google Cloud Platform.\n* Learn how to deploy and manage machine learning models on the cloud.\n* Explore cloud-based data storage and processing services.\n\n**4. Docker and Kubernetes:**\n\n* Learn what Docker is and how to use it for containerization.\n* Understand Kubernetes and its role in containerized environment.\n* Explore tools like Docker Compose and Kubernetes for deploying and managing ML pipelines.\n\n**5. Data Pipeline Tools:**\n\n* Choose a data pipeline tool such as Airflow, Apache Kafka, or Apache Spark Streaming.\n* Learn how to design, execute, and monitor data pipelines for ML training and deployment.\n\n**6. Model Training and Optimization:**\n\n* Explore techniques for training and optimizing machine learning models, such as hyperparameter tuning and regularization.\n* Learn about data augmentation and early stopping for model improvement.\n\n**7. Containerization and Packaging:**\n\n* Understand the concept of containerization and its benefits for portability.\n* Learn how to package and deploy ML models as Docker images or Kubernetes deployments.\n\n**8. Security and Governance:**\n\n* Implement security measures to protect ML models and data during deployment.\n* Understand the importance of data governance and compliance.\n\n**9. Continuous Monitoring and Maintenance:**\n\n* Set up monitoring and alerting systems to track model performance and system health.\n* Implement proactive maintenance processes to address potential issues.\n\n**10. Case-Based Learning:**\n\n* Choose specific ML deployment use cases, such as building a custom ML pipeline or deploying a model to a production environment.\n* Follow the steps and best practices for deploying that particular use case.\n\n**Additional Tips:**\n\n* Join online communities and forums to connect with other ML deployment experts.\n* Participate in online courses and webinars to stay updated on industry trends.\n* Practice by building and deploying small ML projects.\n* Seek mentorship from experienced ML engineers or data scientists. word count is: 358'

# %%
merged_chain.get_graph().print_ascii()
# Out:
#               +-------------+
#               | PromptInput |
#               +-------------+
#                       *
#                       *
#                       *
#              +----------------+
#              | PromptTemplate |
#              +----------------+
#                       *
#                       *
#                       *
#                +------------+
#                | ChatOllama |
#                +------------+
#                       *
#                       *
#                       *
#             +-----------------+
#             | StrOutputParser |
#             +-----------------+
#                       *
#                       *
#                       *
#      +-------------------------------+
#      | Parallel<roadmap,length>Input |
#      +-------------------------------+
#               **            ***
#             **                 **
#           **                     **
# +-------------+              +------------+
# | Passthrough |              | word_count |
# +-------------+              +------------+
#               **            ***
#                 **        **
#                   **    **
#      +--------------------------------+
#      | Parallel<roadmap,length>Output |
#      +--------------------------------+
